# %% [markdown]
# # SEC Filings

# %%
df = pd.read_excel("litigation-funding-awards-list//litigation-funding-top.xlsx")

# %%
df
# Out:
#     Unnamed: 0                             Firm          Location  \
# 0          NaN                 Affiniti Finance            London
# 1          NaN                          Asertis          Cheshire
# 2          NaN                 Augusta Ventures            London
# 3          NaN            Balance Legal Capital            London
# 4          NaN              Bench Walk Advisors  Wilmington, Del.
# 5          NaN                     Brickell Key             Miami
# 6          NaN                  Burford Capital          New York
# 7          NaN                   Curiam Capital          New York
# 8          NaN           Delta Capital Partners           Chicago
# 9          NaN                          Deminor            London
# 10         NaN                   Drumcliffe LLC         Baltimore
# 11         NaN                   Exton Advisors            London
# 12         NaN        Fortress Investment Group          New York
# 13         NaN                      GLS Capital           Chicago
# 14         NaN                          Harbour            London
# 15         NaN                        Innsworth            London
# 16         NaN                    Juris Capital           Chicago
# 17         NaN                    Lake Whillans          New York
# 18         NaN                        LexShares          New York
# 19         NaN      LionFish Litigation Finance            London
# 20         NaN    Litigation Capital Management            London
# 21         NaN                 Longford Capital           Chicago
# 22         NaN            Manolete Partners PLC            London
# 23         NaN                            Marsh           Chicago
# 24         NaN                         Nivalion            Munich
# 25         NaN                   Omni Bridgeway          New York
# 26         NaN  Orchard Global Asset Management            London
# 27         NaN               Parabellum Capital          New York
# 28         NaN               Profile Investment            London
# 29         NaN     Redbreast Litigation Finance         The Hague
# 30         NaN                Redress Solutions            London
# 31         NaN                  Statera Capital           Chicago
# 32         NaN              The D.E. Shaw Group          New York
# 33         NaN                  Therium Capital          New York
# 34         NaN                     TRGP Capital          New York
# 35         NaN                 Validity Finance          New York
# 36         NaN                   Vannin Capital            London
# 37         NaN                          Veridis             Tampa
# 38         NaN     Woodsford Litigation Funding          New York
#
#    Lawdragon Global 100 Leaders in Legal Finance 2021 Chambers Ranking  \
# 0                                                 NaN              NaN
# 1                                                 NaN        Band-5-UK
# 2   Lawdragon Global 100 Leaders in Legal Finance ...        Band-3-UK
# 3   Lawdragon Global 100 Leaders in Legal Finance ...        Band-3-UK
# 4   Lawdragon Global 100 Leaders in Legal Finance ...           Band-4
# 5                                                 NaN              NaN
# 6   Lawdragon Global 100 Leaders in Legal Finance ...           Band-1
# 7   Lawdragon Global 100 Leaders in Legal Finance ...           Band-4
# 8   Lawdragon Global 100 Leaders in Legal Finance ...              NaN
# 9   Lawdragon Global 100 Leaders in Legal Finance ...              NaN
# 10                                                NaN              NaN
# 11  Lawdragon Global 100 Leaders in Legal Finance ...              NaN
# 12  Lawdragon Global 100 Leaders in Legal Finance ...           Band-1
# 13  Lawdragon Global 100 Leaders in Legal Finance ...           Band-3
# 14  Lawdragon Global 100 Leaders in Legal Finance ...        Band-1-UK
# 15                                                NaN              NaN
# 16  Lawdragon Global 100 Leaders in Legal Finance ...              NaN
# 17  Lawdragon Global 100 Leaders in Legal Finance ...           Band-3
# 18  Lawdragon Global 100 Leaders in Legal Finance ...           Band-5
# 19                                                NaN        Band-5-UK
# 20  Lawdragon Global 100 Leaders in Legal Finance ...        Band-3-UK
# 21  Lawdragon Global 100 Leaders in Legal Finance ...           Band-2
# 22                                                NaN        Band-5-UK
# 23                                                NaN              NaN
# 24  Lawdragon Global 100 Leaders in Legal Finance ...              NaN
# 25  Lawdragon Global 100 Leaders in Legal Finance ...           Band-1
# 26                                                NaN        Band-4-UK
# 27  Lawdragon Global 100 Leaders in Legal Finance ...           Band-3
# 28                                                NaN              NaN
# 29  Lawdragon Global 100 Leaders in Legal Finance ...              NaN
# 30                                                NaN              NaN
# 31  Lawdragon Global 100 Leaders in Legal Finance ...              NaN
# 32  Lawdragon Global 100 Leaders in Legal Finance ...              NaN
# 33  Lawdragon Global 100 Leaders in Legal Finance ...           Band-2
# 34  Lawdragon Global 100 Leaders in Legal Finance ...              NaN
# 35  Lawdragon Global 100 Leaders in Legal Finance ...           Band-3
# 36  Lawdragon Global 100 Leaders in Legal Finance ...        Band-3-UK
# 37  Lawdragon Global 100 Leaders in Legal Finance ...           Band-5
# 38  Lawdragon Global 100 Leaders in Legal Finance ...           Band-4
#
#    WWL_Third_Party_Funding                                               site  \
# 0                      WWL                     https://affinitifinance.co.uk/
# 1                      NaN  About Us | Commercial Disputes & Insolvency Li...
# 2                      WWL                   https://www.augustaventures.com/
# 3                      WWL  https://www.balancelegalcapital.com/tag/litiga...
# 4                      WWL                             https://benchwalk.com/
# 5                      WWL                             https://www.bkaml.com/
# 6                      WWL                    https://www.burfordcapital.com/
# 7                      WWL                            https://www.curiam.com/
# 8                      NaN                          https://www.deltacph.com/
# 9                      NaN                        https://drs.deminor.com/en/
# 10                     WWL                     http://drumcliffepartners.com/
# 11                     NaN                         https://extonadvisors.com/
# 12                     WWL                          https://www.fortress.com/
# 13                     WWL                            https://www.glscap.com/
# 14                     WWL              https://harbourlitigationfunding.com/
# 15                     WWL                         https://www.innsworth.com/
# 16                     NaN                  https://www.juriscapitalcorp.com/
# 17                     WWL                  https://lakewhillans.com/contact/
# 18                     NaN                         https://www.lexshares.com/
# 19                     NaN                            https://www.lflf.co.uk/
# 20                     WWL                        https://www.lcmfinance.com/
# 21                     WWL  https://www.longfordcapital.com/litigation-fin...
# 22                     WWL                 https://www.manolete-partners.com/
# 23                     WWL                 https://www.marsh.com/uk/home.html
# 24                     NaN                              https://nivalion.com/
# 25                     WWL                         https://omnibridgeway.com/
# 26                     WWL                  https://www.orchardgroup.com/home
# 27                     WWL                     https://www.parabellumcap.com/
# 28                     WWL                     https://profileinvestment.com/
# 29                     NaN                             https://redbreast.com/
# 30                     WWL                    https://redresssolutions.co.uk/
# 31                     NaN                            https://stateracap.com/
# 32                     NaN                            https://www.deshaw.com/
# 33                     WWL                        https://www.therium.com/us/
# 34                     NaN                           https://www.trgpcap.com/
# 35                     WWL                       https://validityfinance.com/
# 36                     NaN                                https://vannin.com/
# 37                     NaN                       https://www.veridismgmt.com/
# 38                     WWL            https://woodsfordlitigationfunding.com/
#
#         Unnamed: 7  Funding  News
# 0              NaN      NaN   NaN
# 1              NaN      NaN   NaN
# 2              NaN      NaN   NaN
# 3              NaN      NaN   NaN
# 4              NaN      NaN   NaN
# 5              NaN      NaN   NaN
# 6   Public Company      NaN   NaN
# 7              NaN      NaN   NaN
# 8              NaN      NaN   NaN
# 9              NaN      NaN   NaN
# 10             NaN      NaN   NaN
# 11             NaN      NaN   NaN
# 12             NaN      NaN   NaN
# 13             NaN      NaN   NaN
# 14             NaN      NaN   NaN
# 15             NaN      NaN   NaN
# 16             NaN      NaN   NaN
# 17             NaN      NaN   NaN
# 18             NaN      NaN   NaN
# 19             NaN      NaN   NaN
# 20             NaN      NaN   NaN
# 21             NaN      NaN   NaN
# 22             NaN      NaN   NaN
# 23             NaN      NaN   NaN
# 24             NaN      NaN   NaN
# 25             NaN      NaN   NaN
# 26             NaN      NaN   NaN
# 27             NaN      NaN   NaN
# 28             NaN      NaN   NaN
# 29             NaN      NaN   NaN
# 30             NaN      NaN   NaN
# 31             NaN      NaN   NaN
# 32             NaN      NaN   NaN
# 33             NaN      NaN   NaN
# 34             NaN      NaN   NaN
# 35             NaN      NaN   NaN
# 36             NaN      NaN   NaN
# 37             NaN      NaN   NaN
# 38             NaN      NaN   NaN

# %%
#

# %% [markdown]
# Description

# %% [markdown]
# Source: https://www.sec.gov/dera/data/financial-statement-and-notes-data-set.html
#
#
# Central Index Key: 0001714174
#
#
# <SEC-DOCUMENT>0001104659-22-022919.txt : 20220214
# <SEC-HEADER>0001104659-22-022919.hdr.sgml : 20220214
# <ACCEPTANCE-DATETIME>20220214163026
# ACCESSION NUMBER:		0001104659-22-022919
# CONFORMED SUBMISSION TYPE:	6-K
# PUBLIC DOCUMENT COUNT:		3
# CONFORMED PERIOD OF REPORT:	20220214
# FILED AS OF DATE:		20220214
# DATE AS OF CHANGE:		20220214
#
# FILER:
#
# 	COMPANY DATA:
# 		COMPANY CONFORMED NAME:			Burford Capital Ltd
# 		CENTRAL INDEX KEY:			0001714174
# 		STANDARD INDUSTRIAL CLASSIFICATION:	FINANCE SERVICES [6199]
# 		IRS NUMBER:				000000000
# 		STATE OF INCORPORATION:			Y7
# 		FISCAL YEAR END:			1231
#
# 	FILING VALUES:
# 		FORM TYPE:		6-K
# 		SEC ACT:		1934 Act
# 		SEC FILE NUMBER:	001-39511
# 		FILM NUMBER:		22632901
#
# 	BUSINESS ADDRESS:
# 		STREET 1:		OAK HOUSE
# 		STREET 2:		HIRZEL STREET
# 		CITY:			ST PETER PORT
# 		STATE:			Y7
# 		ZIP:			GY1 2NP
# 		BUSINESS PHONE:		44 (0)1481 723450
#
# 	MAIL ADDRESS:
# 		STREET 1:		OAK HOUSE
# 		STREET 2:		HIRZEL STREET
# 		CITY:			ST PETER PORT
# 		STATE:			Y7
# 		ZIP:			GY1 2NP

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/sm/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# SEC Example: Burford Capital Ltd.
#
# https://www.sec.gov/edgar/browse/?CIK=1714174&owner=exclude

# %%
#SEC data types

# %% [markdown]
# TXT dataset
#
# The TXT data set contains non-numeric data, one row per data point in the financial statements. The source for the table is the "as filed" XBRL filer submissions.
#
# * adsh: Accession Number. The 20-character string formed from the 18-digit number assigned by the Commission to each EDGAR submission. *
# * tag: The unique identifier (name) for a tag in a specific taxonomy release.
# * version: For a standard tag, an identifier for the taxonomy; otherwise the accession number where the tag was defined.  For example, "invest/2013" indicates that the tag is defined in the 2013 INVEST taxonomy.
# * ddate: The end date for the data value, rounded to the nearest month end.
# * qtrs: The count of the number of quarters represented by the data value, rounded to the nearest whole number. A point in time value is represented by 0.
# * durp: The difference between the reported fact duration and the quarter duration (qtrs), expressed as a fraction of 1.  For example, a fact with duration of 120 days rounded to a 91-day quarter has a durp value of 29/91 = +0.3187.
# * datp: The date proximity in number of days between end date reported and month-end rounded date.
# * dimh: The 32-byte hexadecimal key for the dimensional information in the DIM data set. *
# * coreg: If specified, indicates a specific co-registrant, the parent company, or other entity (e.g., guarantor).  NULL indicates the consolidated entity.  Note that this value is a function of the dimension segments.
# * escaped: Flag indicating whether the value has had tags removed.
# * footnote: The plain text of any superscripted footnotes on the value, as shown on the page, truncated to 512 characters, or if there is no footnote, then this field will be blank.
# *context: The value, with all whitespace normalized, that is, all sequences of line feeds, carriage returns, tabs, non-breaking spaces, and spaces having been collapsed to a single space, and no leading or trailing spaces.  Escaped XML that appears in EDGAR "Text Block" tags is processed to remove all mark-up (comments, processing instructions, elements, attributes).  The value is truncated to a maximum number of bytes.  The resulting text is not intended for end user display but only for text analysis applications.

# %%
df_test1 = pd.read_csv("sec-data//2021_12_notes//txt.tsv", 
                 sep='\t', 
                 na_values=[0],
                 encoding="latin-1")
df_test1
# Out:
# /Users/sm/.pyenv/versions/3.10.0/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                         adsh  \
# 0       0001104659-21-149306
# 1       0001104659-21-149560
# 2       0001104659-21-149308
# 3       0001104659-21-149308
# 4       0001104659-21-149304
# ...                      ...
# 216339  0001851734-21-000150
# 216340  0001851734-21-000150
# 216341  0001851734-21-000150
# 216342  0001851734-21-000150
# 216343  0001874178-21-000006
#
#                                                       tag  \
# 0       OrganizationConsolidationAndPresentationOfFina...
# 1       OrganizationConsolidationAndPresentationOfFina...
# 2       OrganizationConsolidationAndPresentationOfFina...
# 3       OrganizationConsolidationAndPresentationOfFina...
# 4       OrganizationConsolidationAndPresentationOfFina...
# ...                                                   ...
# 216339  PreferredStockConvertibleConvertibilityPeriodA...
# 216340                 ClassOfWarrantOrRightVestingPeriod
# 216341                 ClassOfWarrantOrRightVestingPeriod
# 216342  OptionsAndWarrantsExpirationTermFollowingTheFi...
# 216343  TemporaryEquityAndStockholdersEquityDisclosure...
#
#                      version     ddate  qtrs  iprx   lang   dcml      durp  \
# 0               us-gaap/2020  20210930   3.0   NaN  en-US  32767  0.019179
# 1               us-gaap/2020  20210930   3.0   NaN  en-US  32767  0.019179
# 2               us-gaap/2020  20201231   4.0   NaN  en-US  32767  0.482192
# 3               us-gaap/2020  20210930   3.0   NaN  en-US  32767  0.019179
# 4               us-gaap/2020  20201231   4.0   NaN  en-US  32767       NaN
# ...                      ...       ...   ...   ...    ...    ...       ...
# 216339  0001851734-21-000150  20210930   4.0   NaN  en-US  32767  0.010959
# 216340  0001851734-21-000150  20210930   4.0   NaN  en-US  32767  0.010959
# 216341  0001851734-21-000150  20210930   4.0   NaN  en-US  32767  0.010959
# 216342  0001851734-21-000150  20210930   4.0   NaN  en-US  32767  0.010959
# 216343  0001874178-21-000006  20210930   3.0   NaN  en-US  32767  0.019179
#
#         datp                                dimh  dimn coreg  escaped  \
# 0        NaN                          0x00000000   NaN   NaN      1.0
# 1        NaN                          0x00000000   NaN   NaN      1.0
# 2        NaN                          0x00000000   NaN   NaN      1.0
# 3        NaN                          0x00000000   NaN   NaN      1.0
# 4        NaN                          0x00000000   NaN   NaN      1.0
# ...      ...                                 ...   ...   ...      ...
# 216339   NaN  0x4691ecbf0e988ab14c2ac92e14526f4d   1.0   NaN      NaN
# 216340   NaN  0x4900faa658fb084ad16a3fd6fd5a0af9   2.0   NaN      NaN
# 216341   NaN  0x3af4923144b01b3d138532e549776583   2.0   NaN      NaN
# 216342   NaN  0x5cdb3048866236758400d88561b717f0   2.0   NaN      NaN
# 216343   NaN                          0x00000000   NaN   NaN      1.0
#
#          srclen   txtlen footnote  footlen  \
# 0       14355.0  10701.0      NaN      NaN
# 1       12319.0   9175.0      NaN      NaN
# 2       17429.0  14660.0      NaN      NaN
# 3       18120.0  14832.0      NaN      NaN
# 4       16072.0  11749.0      NaN      NaN
# ...         ...      ...      ...      ...
# 216339      5.0      5.0      NaN      NaN
# 216340      3.0      3.0      NaN      NaN
# 216341      3.0      3.0      NaN      NaN
# 216342      3.0      3.0      NaN      NaN
# 216343  47138.0   6365.0      NaN      NaN
#
#                                                   context  \
# 0       Duration_1_1_2021_To_9_30_2021_RwCPA6c1GkyrMOE...
# 1       Duration_1_1_2021_To_9_30_2021_-D0OjqPQ9UywHQZ...
# 2       Duration_2_14_2020_To_12_31_2020_1uTU7qmFN0u03...
# 3       Duration_1_1_2021_To_9_30_2021_J8h0TwBpskSZgk7...
# 4       Duration_1_1_2020_To_12_31_2020_yzcIljh5FkytHG...
# ...                                                   ...
# 216339  d_2020-10-01_2021-09-30_StatementClassOfStockA...
# 216340  d_2020-10-01_2021-09-30_RangeAxis-MinimumMembe...
# 216341  d_2020-10-01_2021-09-30_RangeAxis-MaximumMembe...
# 216342  d_2020-10-01_2021-09-30_PlanNameAxis-The2012Pl...
# 216343  ic7191b53929145e2b6408810a6dc89c1_D20210101-20...
#
#                                                     value
# 0       1. Organization, Business Operations. Incorpor...
# 1       1. NATURE OF BUSINESS AND BASIS OF PRESENTATIO...
# 2       NOTE 1. DESCRIPTION OF ORGANIZATION AND BUSINE...
# 3       NOTE 1. DESCRIPTION OF ORGANIZATION AND BUSINE...
# 4       Note 1  Organization, Business Operations and ...
# ...                                                   ...
# 216339                                              P540D
# 216340                                                P2Y
# 216341                                                P3Y
# 216342                                                P5Y
# 216343  CONTINGENTLY REDEEMABLE CONVERTIBLE PREFERRED ...
#
# [216344 rows x 20 columns]

# %%
df_test2 = pd.read_csv("sec-data//2021_12_notes//num.tsv", 
                 sep='\t', 
                 na_values=[0],
                 encoding="latin-1")
df_test2
# Out:
#                         adsh  \
# 0       0001062993-21-011894
# 1       0001062993-21-011894
# 2       0001193125-21-344339
# 3       0001193125-21-344339
# 4       0001193125-21-344339
# ...                      ...
# 780134  0001213900-21-068164
# 780135  0001213900-21-068164
# 780136  0001213900-21-068164
# 780137  0001493152-21-032787
# 780138  0001493152-21-032787
#
#                                                       tag  \
# 0       WeightedAverageExercisePriceOfShareOptionsOuts...
# 1                   EachSharePurchaseWarrantAssessedValue
# 2                  ProfitLossAttributableToOwnersOfParent
# 3                                          NotionalAmount
# 4       IncreaseDecreaseThroughNetExchangeDifferencesP...
# ...                                                   ...
# 780134                                      AssetsCurrent
# 780135                         DueToRelatedPartiesCurrent
# 780136                                           Goodwill
# 780137                                    DeferredRevenue
# 780138      LitigationSettlementAmountAwardedToOtherParty
#
#                      version     ddate  qtrs  uom  \
# 0                  ifrs/2020  20191231   NaN  CAD
# 1       0001062993-21-011894  20171231   NaN  CAD
# 2                  ifrs/2020  20201031   4.0  CAD
# 3                  ifrs/2020  20211031   NaN  CAD
# 4                  ifrs/2020  20201031   4.0  CAD
# ...                      ...       ...   ...  ...
# 780134          us-gaap/2021  20201231   NaN  USD
# 780135          us-gaap/2021  20201231   NaN  USD
# 780136          us-gaap/2021  20201231   NaN  USD
# 780137          us-gaap/2021  20210930   NaN  USD
# 780138          us-gaap/2021  20210430   NaN  USD
#
#                                       dimh  iprx         value footnote  \
# 0       0x833c5d9b45ae0f823524a9499bd2029b   NaN  1.400000e-01      NaN
# 1       0xb36e98a1603d71c9130dc58a98eb1359   NaN  4.000000e-01      NaN
# 2                               0x00000000   NaN  1.143200e+10      NaN
# 3       0x330691fdeafe2e135ffc8330e5171705   NaN  5.633500e+10      NaN
# 4       0x99090c3ff88704202dc8610a2a65a5a0   NaN  3.800000e+07      NaN
# ...                                    ...   ...           ...      ...
# 780134  0x3c420701a0f700d08abfac656e79c150   NaN  2.587843e+07      NaN
# 780135                          0x00000000   2.0  1.533700e+05      NaN
# 780136                          0x00000000   1.0  7.097050e+05      NaN
# 780137                          0x00000000   NaN           NaN      NaN
# 780138  0x7c32cd7a92059d3937907c64606f5c7a   NaN  6.000000e+04      NaN
#
#         footlen  dimn coreg      durp  datp  dcml
# 0           NaN   2.0   NaN       NaN   NaN   2.0
# 1           NaN   1.0   NaN       NaN  -8.0   2.0
# 2           NaN   NaN   NaN       NaN   NaN  -6.0
# 3           NaN   3.0   NaN       NaN   NaN  -6.0
# 4           NaN   3.0   NaN       NaN   NaN  -6.0
# ...         ...   ...   ...       ...   ...   ...
# 780134      NaN   1.0   NaN       NaN   NaN   NaN
# 780135      NaN   NaN   NaN       NaN   NaN   NaN
# 780136      NaN   NaN   NaN       NaN   NaN   NaN
# 780137      NaN   NaN   NaN       NaN   NaN   NaN
# 780138      NaN   1.0   NaN -0.010958   1.0   NaN
#
# [780139 rows x 16 columns]

# %%
df_test3 = pd.read_csv("sec-data//2021_12_notes//pre.tsv", 
                 sep='\t', 
                 na_values=[0],
                 encoding="latin-1")
df_test3
# Out:
#                         adsh  report  line stmt  inpth  \
# 0       0001534992-21-000085      41    17  NaN    NaN
# 1       0000726958-21-000136      25    11  NaN    NaN
# 2       0000726958-21-000136      25    10  NaN    NaN
# 3       0000726958-21-000136      25     9  NaN    NaN
# 4       0001104659-21-148150      35     4  NaN    NaN
# ...                      ...     ...   ...  ...    ...
# 724289  0001493152-21-032787      25    25  NaN    NaN
# 724290  0001493152-21-032787      23    26  NaN    NaN
# 724291  0001493152-21-032787      29    25  NaN    NaN
# 724292  0001140361-21-043409       1     6  NaN    NaN
# 724293  0001140361-21-043409       1     5  NaN    NaN
#
#                                                       tag  \
# 0                                                      FL
# 1                                                      IA
# 2                                                      IL
# 3                                                      NE
# 4                                                      CA
# ...                                                   ...
# 724289                                WarrantMemberMember
# 724290                  WarrantsToPurchaseSharePercentage
# 724291                           WilsonBoulevardIncMember
# 724292  UnitsEachConsistingOfOneClassAOrdinaryShareAnd...
# 724293  WarrantsEachWholeWarrantExercisableForOneClass...
#
#                      version       prole  \
# 0                  stpr/2018  terseLabel
# 1                  stpr/2018  terseLabel
# 2                  stpr/2018  terseLabel
# 3                  stpr/2018  terseLabel
# 4                  stpr/2018  terseLabel
# ...                      ...         ...
# 724289  0001493152-21-032787       label
# 724290  0001493152-21-032787       label
# 724291  0001493152-21-032787       label
# 724292  0001140361-21-043409       label
# 724293  0001140361-21-043409       label
#
#                                                    plabel  negating
# 0                                                 Florida       NaN
# 1                                                    Iowa       NaN
# 2                                                Illinois       NaN
# 3                                                Nebraska       NaN
# 4                                              California       NaN
# ...                                                   ...       ...
# 724289                            Warrant Member [Member]       NaN
# 724290                                Warrant to purchase       NaN
# 724291                      Wilson Boulevard Inc [Member]       NaN
# 724292  Units, each consisting of one Class A ordinary...       NaN
# 724293  Warrants, each whole warrant exercisable for o...       NaN
#
# [724294 rows x 10 columns]

# %%
df_test4 = pd.read_csv("sec-data//2021_12_notes//cal.tsv", 
                 sep='\t', 
                 na_values=[0],
                 encoding="latin-1")
df_test4
# Out:
#                        adsh  grp  arc  negative  \
# 0      0001654954-21-013551    3    1         1
# 1      0001477932-21-009337    2    3         1
# 2      0001589526-21-000140   13    2         1
# 3      0000950170-21-005014    2    2         1
# 4      0001589526-21-000140    6    2        -1
# ...                     ...  ...  ...       ...
# 80288  0001193125-21-369238    2   10         1
# 80289  0001193125-21-369238    1   16        -1
# 80290  0001193125-21-369238    3    6         1
# 80291  0001193125-21-369238    3    4         1
# 80292  0001193125-21-369238    1   14        -1
#
#                                                     ptag      pversion  \
# 0             NetCashProvidedByUsedInOperatingActivities  us-gaap/2020
# 1             NetCashProvidedByUsedInOperatingActivities  us-gaap/2020
# 2             NetCashProvidedByUsedInOperatingActivities  us-gaap/2020
# 3             NetCashProvidedByUsedInOperatingActivities  us-gaap/2020
# 4      OtherComprehensiveIncomeLossPensionAndOtherPos...  us-gaap/2020
# ...                                                  ...           ...
# 80288                                        Liabilities  us-gaap/2020
# 80289         NetCashProvidedByUsedInOperatingActivities  us-gaap/2020
# 80290                                      NetIncomeLoss  us-gaap/2020
# 80291                                      NetIncomeLoss  us-gaap/2020
# 80292         NetCashProvidedByUsedInOperatingActivities  us-gaap/2020
#
#                                              ctag              cversion
# 0                                   NetIncomeLoss          us-gaap/2020
# 1                                   NetIncomeLoss          us-gaap/2020
# 2                                   NetIncomeLoss          us-gaap/2020
# 3                                   NetIncomeLoss          us-gaap/2020
# 4                                   NetIncomeLoss          us-gaap/2020
# ...                                           ...                   ...
# 80288                DerivativeWarrantLiabilities  0001193125-21-369238
# 80289  FinancingCostsDerivativeWarrantLiabilities  0001193125-21-369238
# 80290  FinancingCostsDerivativeWarrantLiabilities  0001193125-21-369238
# 80291     InvestmentIncomeEarnedOnTheTrustAccount  0001193125-21-369238
# 80292     InvestmentIncomeEarnedOnTheTrustAccount  0001193125-21-369238
#
# [80293 rows x 8 columns]

# %%
df_test5 = pd.read_csv("sec-data//2021_12_notes//dim.tsv", 
                 sep='\t', 
                 na_values=[0],
                 encoding="latin-1")
df_test5
# Out:
#                                   dimhash  \
# 0                              0x00000000
# 1      0x2977c24bdd0932ed12e8bdab0ac5507a
# 2      0x2af191f282beda4ecf1c9d6c545d255d
# 3      0x32680e2fbdb93c7342b6017365c1e338
# 4      0x39a8013dc39c3ca9a264d4351b983331
# ...                                   ...
# 50231  0x7e4053ad3d04f9c2c255b10427ab272d
# 50232  0x89ad482868e6911ce89ad0b3c376ae6c
# 50233  0x92f15b6d746537a8cf84599499ad602e
# 50234  0x6dbf575abf26da76ea2ede4050d39396
# 50235  0xe21f7f7271ef2cd3555ed7875213c3af
#
#                                                 segments  segt
# 0                                                    NaN   NaN
# 1      FairValueByFairValueHierarchyLevel=FairValueIn...   NaN
# 2      FairValueByFairValueHierarchyLevel=FairValueIn...   NaN
# 3      ReserveQuantitiesByTypeOfReserve=NaturalGasRes...   NaN
# 4      PropertyPlantAndEquipmentByType=OilAndGasPrope...   NaN
# ...                                                  ...   ...
# 50231                 BusinessAcquisition=CapinnovetInc;   NaN
# 50232       BusinessAcquisition=DelfUkLtd;Range=Minimum;   NaN
# 50233       BusinessAcquisition=DelfUkLtd;Range=Maximum;   NaN
# 50234                     BusinessAcquisition=DelfUkLtd;   NaN
# 50235   BusinessAcquisition=CapinnovetInc;Range=Maximum;   NaN
#
# [50236 rows x 3 columns]

# %%
df_test6 = pd.read_csv("sec-data//2021_12_notes//tag.tsv", 
                 sep='\t', 
                 na_values=[0],
                 encoding="latin-1")
df_test6
# Out:
#                                                       tag  \
# 0                                                      FL
# 1                                                      IA
# 2                                                      IL
# 3                                                      NE
# 4                                                      CA
# ...                                                   ...
# 123836                                WarrantMemberMember
# 123837                  WarrantsToPurchaseSharePercentage
# 123838                           WilsonBoulevardIncMember
# 123839  UnitsEachConsistingOfOneClassAOrdinaryShareAnd...
# 123840  WarrantsEachWholeWarrantExercisableForOneClass...
#
#                      version  custom  abstract datatype iord crdr  \
# 0                  stpr/2018     NaN       1.0   member  NaN  NaN
# 1                  stpr/2018     NaN       1.0   member  NaN  NaN
# 2                  stpr/2018     NaN       1.0   member  NaN  NaN
# 3                  stpr/2018     NaN       1.0   member  NaN  NaN
# 4                  stpr/2018     NaN       1.0   member  NaN  NaN
# ...                      ...     ...       ...      ...  ...  ...
# 123836  0001493152-21-032787     1.0       NaN   member    D  NaN
# 123837  0001493152-21-032787     1.0       NaN  percent    D  NaN
# 123838  0001493152-21-032787     1.0       NaN   member    D  NaN
# 123839  0001140361-21-043409     1.0       1.0   member  NaN  NaN
# 123840  0001140361-21-043409     1.0       1.0   member  NaN  NaN
#
#                                                    tlabel  \
# 0                                                 FLORIDA
# 1                                                    IOWA
# 2                                                ILLINOIS
# 3                                                NEBRASKA
# 4                                              CALIFORNIA
# ...                                                   ...
# 123836                            Warrant Member [Member]
# 123837                                Warrant to purchase
# 123838                      Wilson Boulevard Inc [Member]
# 123839  Units, each consisting of one Class A ordinary...
# 123840  Warrants, each whole warrant exercisable for o...
#
#                                   doc
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 123836        Warrant Member [Member]
# 123837           Warrant to purchase.
# 123838  Wilson Boulevard Inc [Member]
# 123839                            NaN
# 123840                            NaN
#
# [123841 rows x 9 columns]

# %% [markdown]
# The submissions data set contains summary information about an entire EDGAR submission. Some fields were sourced directly from EDGAR submission information, while other fields of data were sourced from the Interactive Data exhibits of the submission. Note: EDGAR derived fields represent the most recent EDGAR assignment as of a given filing's submission date and do not necessarily represent the most current assignments.

# %%
df_test7 = pd.read_csv("sec-data//2020q1_notes//sub.tsv", 
                 sep='\t', 
                 na_values=[0],
                 encoding="latin-1")
df_test7
# Out:
#                        adsh      cik                       name     sic  \
# 0      0000004977-20-000002     4977                  AFLAC INC  6321.0
# 1      0000018498-20-000002    18498                GENESCO INC  5661.0
# 2      0000052795-20-000004    52795  ANIXTER INTERNATIONAL INC  5063.0
# 3      0000082811-20-000002    82811          REGAL BELOIT CORP  3621.0
# 4      0000091767-20-000003    91767         SONOCO PRODUCTS CO  2650.0
# ...                     ...      ...                        ...     ...
# 13556  0001564590-20-014183  1540755              ANAPLAN, INC.  7372.0
# 13557  0001564590-20-014171  1722992     SMTA LIQUIDATING TRUST  6798.0
# 13558  0001564590-20-014167  1770141          GIGCAPITAL2, INC.  6770.0
# 13559  0001564590-20-014165  1095981    PLUS THERAPEUTICS, INC.  3841.0
# 13560  0001564590-20-014162  1673772    RAPT THERAPEUTICS, INC.  2834.0
#
#       countryba stprba               cityba       zipba  \
# 0            US     GA             COLUMBUS       31999
# 1            US     TN            NASHVILLE       37217
# 2            US     IL             GLENVIEW       60026
# 3            US     WI               BELOIT       53511
# 4            US     SC           HARTSVILLE  29551-0160
# ...         ...    ...                  ...         ...
# 13556        US     CA        SAN FRANCISCO       94105
# 13557        US     TX               DALLAS       75201
# 13558        US     CA            PALO ALTO       94111
# 13559        US     TX               AUSTIN       78756
# 13560        US     CA  SOUTH SAN FRANCISCO       94080
#
#                                   bas1         bas2  ...  \
# 0                      1932 WYNNTON RD          NaN  ...
# 1      GENESCO PK 1415 MURFREESBORO RD          NaN  ...
# 2                    2301 PATRIOT BLVD          NaN  ...
# 3                         200 STATE ST          NaN  ...
# 4                  ONE NORTH SECOND ST  P O BOX 160  ...
# ...                                ...          ...  ...
# 13556              50 HAWTHORNE STREET          NaN  ...
# 13557              2727 N. HARWOOD ST.     STE. 300  ...
# 13558               2479 E BAYSHORE RD      STE 200  ...
# 13559              4200 MARATHON BLVD.    SUITE 200  ...
# 13560                561 ECCLES AVENUE          NaN  ...
#
#                     accepted prevrpt detail                        instance  \
# 0      2020-01-02 07:45:00.0     NaN    NaN  afl8-kxdecember2019xot_htm.xml
# 1      2020-01-02 17:05:00.0     NaN    NaN        a8-ktogast010220_htm.xml
# 2      2020-01-02 06:38:00.0     1.0    NaN  a8-kxsecondamendedmerg_htm.xml
# 3      2020-01-02 09:09:00.0     NaN    NaN      a8-kdec272019cover_htm.xml
# 4      2020-01-02 11:55:00.0     1.0    NaN            son-20191231_htm.xml
# ...                      ...     ...    ...                             ...
# 13556  2020-03-30 16:16:00.0     NaN    1.0       plan-10k_20200131_htm.xml
# 13557  2020-03-30 16:10:00.0     NaN    1.0       smta-10k_20191231_htm.xml
# 13558  2020-03-30 16:07:00.0     NaN    1.0                gix-20191231.xml
# 13559  2020-03-30 16:07:00.0     NaN    1.0               pstv-20191231.xml
# 13560  2020-03-30 16:05:00.0     NaN    1.0               rapt-20191231.xml
#
#       nciks aciks   pubfloatusd   floatdate floataxis  floatmems
# 0         1   NaN           NaN         NaN       NaN        NaN
# 1         1   NaN           NaN         NaN       NaN        NaN
# 2         1   NaN           NaN         NaN       NaN        NaN
# 3         1   NaN           NaN         NaN       NaN        NaN
# 4         1   NaN           NaN         NaN       NaN        NaN
# ...     ...   ...           ...         ...       ...        ...
# 13556     1   NaN  5.680000e+09  20190731.0       NaN        NaN
# 13557     1   NaN  3.600000e+08  20190628.0       NaN        NaN
# 13558     1   NaN  1.881879e+08  20190628.0       NaN        NaN
# 13559     1   NaN  5.400000e+06  20190628.0       NaN        NaN
# 13560     1   NaN  1.874000e+08  20191031.0       NaN        NaN
#
# [13561 rows x 40 columns]

# %%
df_test7[df_test7.name.str.contains("OMNI")]
# Out:
#                        adsh     cik                name     sic countryba  \
# 3167   0000926326-20-000003  926326       OMNICELL, INC  3571.0        US
# 3580   0000891092-20-001606   29989  OMNICOM GROUP INC.  7311.0        US
# 3839   0000029989-20-000005   29989  OMNICOM GROUP INC.  7311.0        US
# 4257   0000926326-20-000005  926326       OMNICELL, INC  3571.0        US
# 4871   0000926326-20-000007  926326       OMNICELL, INC  3571.0        US
# 5066   0000891092-20-001829   29989  OMNICOM GROUP INC.  7311.0        US
# 5874   0000891092-20-001901   29989  OMNICOM GROUP INC.  7311.0        US
# 6780   0000926326-20-000010  926326       OMNICELL, INC  3571.0        US
# 11946  0000891092-20-003373   29989  OMNICOM GROUP INC.  7311.0        US
# 13452  0001493152-20-005303  278165         OMNIQ CORP.  7373.0        US
#
#       stprba          cityba  zipba                     bas1 bas2  ...  \
# 3167      CA   MOUNTAIN VIEW  94043  590 E. MIDDLEFIELD ROAD  NaN  ...
# 3580      NY        NEW YORK  10022          437 MADISON AVE  NaN  ...
# 3839      NY        NEW YORK  10022          437 MADISON AVE  NaN  ...
# 4257      CA   MOUNTAIN VIEW  94043  590 E. MIDDLEFIELD ROAD  NaN  ...
# 4871      CA   MOUNTAIN VIEW  94043  590 E. MIDDLEFIELD ROAD  NaN  ...
# 5066      NY        NEW YORK  10022          437 MADISON AVE  NaN  ...
# 5874      NY        NEW YORK  10022          437 MADISON AVE  NaN  ...
# 6780      CA   MOUNTAIN VIEW  94043  590 E. MIDDLEFIELD ROAD  NaN  ...
# 11946     NY        NEW YORK  10022          437 MADISON AVE  NaN  ...
# 13452     UT  SALT LAKE CITY  84119     1865 WEST 2100 SOUTH  NaN  ...
#
#                     accepted prevrpt detail               instance nciks  \
# 3167   2020-02-06 16:08:00.0     NaN    NaN  omcl-20200206_htm.xml     1
# 3580   2020-02-11 07:13:00.0     NaN    NaN       e8341-8k_htm.xml     1
# 3839   2020-02-11 16:48:00.0     NaN    1.0   omc-20191231_htm.xml     1
# 4257   2020-02-13 16:29:00.0     NaN    NaN  omcl-20200212_htm.xml     1
# 4871   2020-02-18 16:08:00.0     NaN    NaN  omcl-20200213_htm.xml     1
# 5066   2020-02-18 19:37:00.0     NaN    NaN       e8397_8k_htm.xml     1
# 5874   2020-02-21 16:27:00.0     NaN    NaN       e8442-8k_htm.xml     1
# 6780   2020-02-26 16:09:00.0     NaN    1.0  omcl-20191231_htm.xml     1
# 11946  2020-03-25 08:39:00.0     NaN    NaN       e9007-8k_htm.xml     1
# 13452  2020-03-30 17:30:00.0     NaN    1.0      omqs-20191231.xml     1
#
#       aciks   pubfloatusd   floatdate floataxis  floatmems
# 3167    NaN           NaN         NaN       NaN        NaN
# 3580    NaN           NaN         NaN       NaN        NaN
# 3839    NaN  1.760762e+10  20190630.0       NaN        NaN
# 4257    NaN           NaN         NaN       NaN        NaN
# 4871    NaN           NaN         NaN       NaN        NaN
# 5066    NaN           NaN         NaN       NaN        NaN
# 5874    NaN           NaN         NaN       NaN        NaN
# 6780    NaN  3.500000e+09  20190628.0       NaN        NaN
# 11946   NaN           NaN         NaN       NaN        NaN
# 13452   NaN  1.280000e+07  20190630.0       NaN        NaN
#
# [10 rows x 40 columns]

# %%
df_test7[df_test7.name.str.contains("MERIDIAN")]
# df_de.query("P0020001 == 0")
# df_alive[df_alive.spc_common == 'honeylocust']
# # residential_df[residential_df.complaint_type.str.contains("noise")]
# Out:
#                        adsh      cik                       name     sic  \
# 1656   0000892251-20-000002   794172    MERIDIAN BIOSCIENCE INC  2835.0
# 1902   0001564590-20-002277  1600125     MERIDIAN BANCORP, INC.  6021.0
# 2184   0000892251-20-000004   794172    MERIDIAN BIOSCIENCE INC  2835.0
# 3782   0001564590-20-004213  1600125     MERIDIAN BANCORP, INC.  6021.0
# 3950   0001193125-20-027769   794172    MERIDIAN BIOSCIENCE INC  2835.0
# 3955   0001193125-20-027468   794172    MERIDIAN BIOSCIENCE INC  2835.0
# 5613   0001193125-20-043212   794172    MERIDIAN BIOSCIENCE INC  2835.0
# 7579   0001564590-20-007376  1600125     MERIDIAN BANCORP, INC.  6021.0
# 8513   0001564590-20-008151  1600125     MERIDIAN BANCORP, INC.  6021.0
# 11873  0001437749-20-005969  1586454  PRIME MERIDIAN HOLDING CO  6022.0
# 12225  0001564590-20-012208  1600125     MERIDIAN BANCORP, INC.  6021.0
# 13443  0001558370-20-003393  1750735              MERIDIAN CORP  6021.0
#
#       countryba stprba       cityba  zipba                     bas1 bas2  ...  \
# 1656         US     OH   CINCINNATI  45244      3471 RIVER HILLS DR  NaN  ...
# 1902         US     MA  EAST BOSTON  02128       10 MERIDIAN STREET  NaN  ...
# 2184         US     OH   CINCINNATI  45244      3471 RIVER HILLS DR  NaN  ...
# 3782         US     MA  EAST BOSTON  02128       10 MERIDIAN STREET  NaN  ...
# 3950         US     OH   CINCINNATI  45244      3471 RIVER HILLS DR  NaN  ...
# 3955         US     OH   CINCINNATI  45244      3471 RIVER HILLS DR  NaN  ...
# 5613         US     OH   CINCINNATI  45244      3471 RIVER HILLS DR  NaN  ...
# 7579         US     MA  EAST BOSTON  02128       10 MERIDIAN STREET  NaN  ...
# 8513         US     MA  EAST BOSTON  02128       10 MERIDIAN STREET  NaN  ...
# 11873        US     FL  TALLAHASSEE  32308  1897 CAPITAL CIRCLE, NE  NaN  ...
# 12225        US     MA  EAST BOSTON  02128       10 MERIDIAN STREET  NaN  ...
# 13443        US     PA      MALVERN  19355    9 OLD LINCOLN HIGHWAY  NaN  ...
#
#                     accepted prevrpt detail                   instance nciks  \
# 1656   2020-01-27 16:08:00.0     1.0    NaN       form8k012720_htm.xml     1
# 1902   2020-01-28 16:11:00.0     NaN    NaN   ebsb-8k_20200128_htm.xml     1
# 2184   2020-01-30 10:54:00.0     1.0    NaN       form8k012920_htm.xml     1
# 3782   2020-02-11 16:11:00.0     NaN    NaN   ebsb-8k_20200207_htm.xml     1
# 3950   2020-02-07 11:46:00.0     NaN    1.0        d842208d10q_htm.xml     1
# 3955   2020-02-07 08:38:00.0     1.0    NaN         d881819d8k_htm.xml     1
# 5613   2020-02-20 14:51:00.0     1.0    NaN         d894550d8k_htm.xml     1
# 7579   2020-02-27 16:11:00.0     NaN    NaN   ebsb-8k_20200227_htm.xml     1
# 8513   2020-03-02 16:13:00.0     NaN    1.0  ebsb-10k_20191231_htm.xml     1
# 11873  2020-03-24 08:04:00.0     NaN    1.0          pmhg-20191231.xml     1
# 12225  2020-03-23 16:13:00.0     NaN    NaN   ebsb-8k_20200320_htm.xml     1
# 13443  2020-03-30 17:31:00.0     NaN    1.0          mrbk-20191231.xml     1
#
#       aciks  pubfloatusd   floatdate floataxis  floatmems
# 1656    NaN          NaN         NaN       NaN        NaN
# 1902    NaN          NaN         NaN       NaN        NaN
# 2184    NaN          NaN         NaN       NaN        NaN
# 3782    NaN          NaN         NaN       NaN        NaN
# 3950    NaN          NaN         NaN       NaN        NaN
# 3955    NaN          NaN         NaN       NaN        NaN
# 5613    NaN          NaN         NaN       NaN        NaN
# 7579    NaN          NaN         NaN       NaN        NaN
# 8513    NaN  953927091.0  20190628.0       NaN        NaN
# 11873   NaN   50378212.0  20190630.0       NaN        NaN
# 12225   NaN          NaN         NaN       NaN        NaN
# 13443   NaN   99618818.0  20190630.0       NaN        NaN
#
# [12 rows x 40 columns]

# %%
len(df_test7)
# Out:
# 13561

# %%
df_test8 = pd.read_csv("sec-data//2021_12_notes//cal.tsv", 
                 sep='\t', 
                 na_values=[0],
                 encoding="latin-1")
df_test8
# Out:
#                        adsh  grp  arc  negative  \
# 0      0001654954-21-013551    3    1         1
# 1      0001477932-21-009337    2    3         1
# 2      0001589526-21-000140   13    2         1
# 3      0000950170-21-005014    2    2         1
# 4      0001589526-21-000140    6    2        -1
# ...                     ...  ...  ...       ...
# 80288  0001193125-21-369238    2   10         1
# 80289  0001193125-21-369238    1   16        -1
# 80290  0001193125-21-369238    3    6         1
# 80291  0001193125-21-369238    3    4         1
# 80292  0001193125-21-369238    1   14        -1
#
#                                                     ptag      pversion  \
# 0             NetCashProvidedByUsedInOperatingActivities  us-gaap/2020
# 1             NetCashProvidedByUsedInOperatingActivities  us-gaap/2020
# 2             NetCashProvidedByUsedInOperatingActivities  us-gaap/2020
# 3             NetCashProvidedByUsedInOperatingActivities  us-gaap/2020
# 4      OtherComprehensiveIncomeLossPensionAndOtherPos...  us-gaap/2020
# ...                                                  ...           ...
# 80288                                        Liabilities  us-gaap/2020
# 80289         NetCashProvidedByUsedInOperatingActivities  us-gaap/2020
# 80290                                      NetIncomeLoss  us-gaap/2020
# 80291                                      NetIncomeLoss  us-gaap/2020
# 80292         NetCashProvidedByUsedInOperatingActivities  us-gaap/2020
#
#                                              ctag              cversion
# 0                                   NetIncomeLoss          us-gaap/2020
# 1                                   NetIncomeLoss          us-gaap/2020
# 2                                   NetIncomeLoss          us-gaap/2020
# 3                                   NetIncomeLoss          us-gaap/2020
# 4                                   NetIncomeLoss          us-gaap/2020
# ...                                           ...                   ...
# 80288                DerivativeWarrantLiabilities  0001193125-21-369238
# 80289  FinancingCostsDerivativeWarrantLiabilities  0001193125-21-369238
# 80290  FinancingCostsDerivativeWarrantLiabilities  0001193125-21-369238
# 80291     InvestmentIncomeEarnedOnTheTrustAccount  0001193125-21-369238
# 80292     InvestmentIncomeEarnedOnTheTrustAccount  0001193125-21-369238
#
# [80293 rows x 8 columns]
